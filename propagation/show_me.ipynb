# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

field_name = f'z=0.001'
image = f'{field_name}.npy'
image_name = f'intensity_{field_name}.png'

figure(figsize=(10, 8), dpi=100)
plt.imshow(np.abs(np.load(f'propagated_fields/sci_lab_intensity_tie_phase/{image}'))**2, cmap='gray')
plt.colorbar()
plt.show()
